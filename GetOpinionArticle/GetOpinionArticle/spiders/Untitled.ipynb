# %%
import json
data = json.load(open("/home/yuyin/Scrapy/GetOpinionArticle/GetOpinionArticle/opnews.json", 'r'))

# %%
ss = "{0} is a {0}"
ss.format("dog")
# Out:
# 'dog is a dog'

# %%
# Out:
# dict_keys(['olympics boxing'])

# %%
data[0]['olympics boxing']
# Out:
# '{    "Kif.Schema" : "Kif.AnswerProviderResponse[1.9]",    "results" : [        {            "Kif.Schema" : "News.VerticalResponse[1.78]",            "response" : [                {                    "moduleName" : "Main",                    "resultSet" : [                        {                            "type" : 1,                            "article" : {                                "title" : "In ‘Creed II,’ the most important victories aren’t the knockouts",                                "url" : "https://www.washingtonpost.com/opinions/2018/12/03/creed-ii-most-important-victories-arent-knockouts/",                                "source" : "The Washington Post",                                "snippet" : "Who wouldn’t want to be No. 1? “Creed II” is a subtle argument that in \ue000boxing\ue001, and in movie credits, coming in second can be surprisingly liberating. Halfway through “Creed II,” former \ue000Olympic\ue001 boxer Ivan Drago (Dolph Lundgren) and his son ...",    
# ...

# %%
new_d = data[0]['results'][0]['response'][0]['resultSet'][0]['article']
#json.dump(new_d, open('json_test.json', 'a'))
new_d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-4291554829f4> in <module>
# ----> 1 new_d = data[0]['olympics boxing'][0]['results'][0]['response'][0]['resultSet'][0]['article']
#       2 #json.dump(new_d, open('json_test.json', 'a'))
#       3 new_d
#
# TypeError: string indices must be integers

# %%
new_new_d = {}
new_new_d['ll'] = new_d
json.loads(str(new_new_d))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-83-58c0c9714e28> in <module>
#       1 new_new_d = {}
#       2 new_new_d['ll'] = new_d
# ----> 3 json.loads(str(new_new_d))
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ...

# %%
scrapy shell "https://www.bing.com/news/search?q=medical+marijuana&qs=n&form=NWRFSH&sp=-1&pq=medical+marijuana&sc=0-29&sk=&cvid=CCAEF3DCCD9C41ACB9A1220F2C1591FD&p1=%5bNewsVertical+UserAugmentation%3d%22%5bqlf%242102%3a15%5d%22%5d&setflight=filteropinion"
# Out:
#   File "<ipython-input-22-102cb44be921>", line 1
#     scrapy shell "https://www.bing.com/news/search?q=medical+marijuana&qs=n&form=NWRFSH&sp=-1&pq=medical+marijuana&sc=0-29&sk=&cvid=CCAEF3DCCD9C41ACB9A1220F2C1591FD&p1=%5bNewsVertical+UserAugmentation%3d%22%5bqlf%242102%3a15%5d%22%5d&setflight=filteropinion"
#                ^
# SyntaxError: invalid syntax

# %%
scrapy crawl OpinionArticle.py
# Out:
#   File "<ipython-input-23-9395413ce25d>", line 1
#     scrapy crawl OpinionArticle.py
#                ^
# SyntaxError: invalid syntax

# %%
python OpinionArticle.py
# Out:
#   File "<ipython-input-24-ef56b107a2f3>", line 1
#     python OpinionArticle.py
#                         ^
# SyntaxError: invalid syntax

# %%
data = json.dumps("['a':'b']")

# %%
json.loads('')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-63-92b68fb0c30e> in <module>
# ----> 1 json.loads("{'a':'b', 'a':'b'}")
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
# ...

# %%
test_dict = [{'a':"b", 'c':["d", "e"]}, {'a':"b", 'c':["d", "e"]}]
j_test_dict = json.dumps(test_dict)
j_test = json.loads('{"a": "b", "c": ["d", "e"]}, {"a": "b", "c": ["d", "e"]}')#(j_test_dict)
j_test_dict
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-113-546e6a7406a2> in <module>
#       1 test_dict = [{'a':"b", 'c':["d", "e"]}, {'a':"b", 'c':["d", "e"]}]
#       2 j_test_dict = json.dumps(test_dict)
# ----> 3 j_test = json.loads('{"a": "b", "c": ["d", "e"]}, {"a": "b", "c": ["d", "e"]}')#(j_test_dict)
#       4 j_test_dict
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
# ...

# %%
json.loads(str(test_dict))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-104-5a0ff9ba1209> in <module>
# ----> 1 json.loads(str(test_dict))
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
# ...

# %%
a = 0
a == None
# Out:
# False

# %%
[item.strip('\n') for item in open('query_set', 'r', encoding='utf8').readlines()]
# Out:
# ['playboy model', 'Michael Cohen', 'Stephen Colbert']
